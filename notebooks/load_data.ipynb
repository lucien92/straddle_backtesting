# %%
import yfinance as yf

msft = yf.Ticker("MSFT") #on fetch les données de Microsoft

# get all stock info
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
# get historical market data
hist = msft.history(period="1mo")
hist.tail()
# Out:
# /home/lucien/Bureau/préparation_stage/quant_project/straddle_backtesting/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                  Open        High         Low       Close  \
# Date
# 2024-02-15 00:00:00-05:00  408.140015  409.130005  404.290009  406.559998
# 2024-02-16 00:00:00-05:00  407.959991  408.290009  403.440002  404.059998
# 2024-02-20 00:00:00-05:00  403.239990  404.489990  398.010010  402.790009
# 2024-02-21 00:00:00-05:00  400.170013  402.290009  397.220001  402.179993
# 2024-02-22 00:00:00-05:00  410.190002  412.799988  408.570007  411.619995
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-02-15 00:00:00-05:00  21825500        0.0           0.0
# ...

# %%
# show actions (dividends, splits, capital gains)
msft.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2024-02-14 00:00:00-05:00       0.75           0.0

# %%
# show share count
msft.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-01-27 00:00:00-05:00    7496869888
# 2022-02-04 00:00:00-05:00    7800719872
# 2022-02-05 00:00:00-05:00    7496869888
# 2022-02-11 00:00:00-05:00    7496869888
# 2022-03-04 00:00:00-05:00    7605040128
#                                 ...
# 2024-02-07 00:00:00-05:00    7430439936
# 2024-02-07 00:00:00-05:00    7432640000
# 2024-02-14 00:00:00-05:00    7430439936
# 2024-02-15 00:00:00-05:00    7430439936
# 2024-02-17 00:00:00-05:00    7430439936
# Length: 129, dtype: int64

# %%
# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-01-28 16:00:00-05:00           NaN           NaN          NaN
# 2024-10-22 06:00:00-04:00           NaN           NaN          NaN
# 2024-07-23 06:00:00-04:00           NaN           NaN          NaN
# 2024-04-23 06:00:00-04:00          2.61           NaN          NaN
# 2024-01-30 16:00:00-05:00          2.78          2.93       0.0534
# 2023-10-24 16:00:00-04:00          2.65          2.99       0.1270
# 2023-07-25 16:00:00-04:00          2.55          2.69       0.0549
# 2023-04-25 16:00:00-04:00          2.23          2.45       0.0981
# 2023-01-24 16:00:00-05:00          2.29          2.32       0.0109
# 2022-10-25 16:00:00-04:00          2.30          2.35       0.0205
# 2022-07-26 16:00:00-04:00          2.29          2.23      -0.0274
# 2022-04-26 16:00:00-04:00          2.19          2.22       0.0160

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# /home/lucien/Bureau/préparation_stage/quant_project/straddle_backtesting/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
data = yf.download("SPY AAPL", period="1mo") #permets de télécharger plusieurs actions en même temps et les afficher dans un tableau
data

#pour accéder seulement à la colonne close

data['Close']
# Out:
# /home/lucien/Bureau/préparation_stage/quant_project/straddle_backtesting/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /home/lucien/Bureau/préparation_stage/quant_project/straddle_backtesting/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  2 of 2 completed
# Ticker            AAPL         SPY
# Date
# 2024-01-22  193.889999  483.450012
# 2024-01-23  195.179993  484.859985
# 2024-01-24  194.500000  485.390015
# 2024-01-25  194.169998  488.029999
# 2024-01-26  192.419998  487.410004
# ...

# %%
#puis à close de SPY

data['Close']['SPY']
# Out:
# Date
# 2024-01-22    483.450012
# 2024-01-23    484.859985
# 2024-01-24    485.390015
# 2024-01-25    488.029999
# 2024-01-26    487.410004
# 2024-01-29    491.269989
# 2024-01-30    490.890015
# 2024-01-31    482.880005
# 2024-02-01    489.200012
# 2024-02-02    494.350006
# 2024-02-05    492.549988
# 2024-02-06    493.980011
# 2024-02-07    498.100006
# 2024-02-08    498.320007
# 2024-02-09    501.200012
# 2024-02-12    500.980011
# 2024-02-13    494.079987
# 2024-02-14    498.570007
# 2024-02-15    502.010010
# 2024-02-16    499.510010
# 2024-02-20    496.760010
# 2024-02-21    497.209991
# 2024-02-22    507.809998
# Name: SPY, dtype: float64

# %%
#conversion de ce dataframe en csv
data.to_csv('/home/lucien/Bureau/préparation_stage/quant_project/straddle_backtesting/data/data.csv')

# %%
#faisons une classe qui load les données avec poour attributs le nom du stock à récupérer, la période. Comme méthode, on aura une méthode qui permet de récupérer les données et une autre qui permet de les sauvegarder en csv
import pandas as pd

class data:
    def __init__(self, stock, period):
        self.stock = stock
        self.period = period
        self.data = yf.download(stock, period=period)
    def save(self, path):
        self.data.to_csv(path)
    def load_from_csv(self, path):
        self.data = pd.read_csv(path)
        return self.data
    def show(self):
        return self.data

# %%
#exemple afficher une instance de classe 

nikkei = data('^N225', '1mo')
nikkei.show()
# Out:
# /home/lucien/Bureau/préparation_stage/quant_project/straddle_backtesting/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2024-01-22  36294.101562  36571.800781  36225.910156  36546.949219
# 2024-01-23  36605.300781  36984.511719  36436.070312  36517.570312
# 2024-01-24  36415.660156  36471.390625  36104.890625  36226.480469
# 2024-01-25  36213.140625  36312.359375  35912.539062  36236.468750
# 2024-01-26  36003.000000  36060.398438  35687.578125  35751.070312
# 2024-01-29  35814.289062  36186.871094  35813.769531  36026.941406
# 2024-01-30  36196.640625  36249.031250  36039.308594  36065.859375
# ...
